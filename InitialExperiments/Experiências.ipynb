# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
! pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.5MB 1.5MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 512kB 9.7MB/s eta 0:00:01
# ...

# %%
! conda env list
# Out:
# /bin/sh: 1: conda: not found

# %%
df = pd.read_csv("ComaSessions.csv")

# %%
df.head()
# Out:
#    ID   "Sex"   "Age"   "Etiology"   "Diagnostic"   "Visual1"   "Visual2"  \
# 1   1       1      41            2              3           4           4
# 2   2       2      43            1              3           5           5
# 3   3       2      67            1              3           3           1
# 4   4       2      65            2              2           2           4
# 5   5       2      63            2              2           4           4
#
#     "Visual3"   "Visual4"   "Visual5"  ...   "BothRatersSession6"  \
# 1           3           2           5  ...                     NA
# 2           5           5           5  ...                     NA
# 3           4           2           2  ...                     NA
# 4           2           2           2  ...                     NA
# 5           4           4           4  ...                     NA
#
#     "BothRatersCertainty6"   "BothRatersSession7"   "BothRatersCertainty7"  \
# ...
